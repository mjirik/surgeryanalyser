# %%
from typing import Union, Optional
from pathlib import Path
import json
import numpy as np
import skimage.io
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde
from loguru import logger
import pandas as pd

HEATMAP_EXPERT_POINTS_PATH = Path("devel/.npy")

# %%
fn = sorted(list(Path(".").glob("*list_of_all_stitches*.xlsx")))[-1]
print(fn)
dfall = pd.read_excel(fn)

if "done_by_expert" not in dfall.columns:
    dfall["done_by_expert"] = dfall["filename"].str.contains("Ekn").astype(float)
    dfall["done_by_expert"] = dfall["done_by_expert"].astype(bool)
# dfall.done_by_expert.value_counts()
# Out:
# list_of_all_stitches_sorted_by_duration.2025-01-13_20-05-36.xlsx

# %%
fn = dfall[dfall["done_by_expert"]==True].filename.values[5]
patch = Path(fn).stem
patch
# Out:
# 'Ekn_Ana_8'

# %%
MEDIA_ROOT = Path("../piglegsurgeryweb/media/")

def get_outputdir(patch:str):
    img_pths = list((MEDIA_ROOT / "upload/").glob(f"*/*{patch}*"))
    mediafile_path = img_pths[-1]
    mediafile_path = mediafile_path.absolute().resolve()

    outputdir = list(list((MEDIA_ROOT ).glob(f"*/*{patch}*.zip"))[-1].parent.glob("*/meta.json"))[-1].parent

    outputdir = outputdir.absolute().resolve()
    return outputdir, mediafile_path

# %%
outputdir, mediafile_path = get_outputdir(patch)
outputdir
mediafile_path
# Out:
# PosixPath('/webapps/piglegsurgery/piglegsurgeryweb/media/upload/20240820-092634_Ekn_Ana_8_539656a54ac190c20b29639678b8c64bc255d01a/Ekn_Ana_8.preview.jpg')

# %%
def compare_distributions_by_l2_distance(pts, points, bw_adjust1=1.0, bw_adjust2=1.0):
    # Compute both KDEs.
    kde_ground = gaussian_kde(pts.T)
    kde_other = gaussian_kde(points.T)

    kde_ground.set_bandwidth(bw_method=kde_ground.factor * bw_adjust1)
    kde_other.set_bandwidth(bw_method=kde_other.factor * bw_adjust2)

    # Define a common grid that covers the support of both datasets.
    x_min = min(pts[:, 0].min(), points[:, 0].min())
    x_max = max(pts[:, 0].max(), points[:, 0].max())
    y_min = min(pts[:, 1].min(), points[:, 1].min())
    y_max = max(pts[:, 1].max(), points[:, 1].max())

    grid_size = 20
    x_grid = np.linspace(x_min, x_max, grid_size)
    y_grid = np.linspace(y_min, y_max, grid_size)
    X, Y = np.meshgrid(x_grid, y_grid)
    grid_coords = np.vstack([X.ravel(), Y.ravel()])

    # Evaluate both KDEs on the grid.
    density_ground = kde_ground(grid_coords).reshape(X.shape)
    density_other  = kde_other(grid_coords).reshape(X.shape)

    # Calculate a similarity measure (for example, L2 distance).
    l2_distance = np.sqrt(np.sum((density_ground - density_other)**2))
    # print("L2 distance between KDEs:", l2_distance)
    return l2_distance


def compare_heatmaps_plot(
        outputdir: Union[str,Path], points_px:Optional[np.array]=None, pix_size_m:Optional[float]=None, filename=None,
        image:Optional[np.array]=None,
        tool_id=0,
        cmap="Greens",
        levels=3
):

    outputdir = Path(outputdir)
    if pix_size_m is None:
        with open(outputdir / "meta.json", "r") as f:
            meta = json.load(f)
        pix_size_m = meta["qr_data"]["pix_size"]

    if points_px is None:
        with open(outputdir / "tracks_points.json", "r") as f:
            tracks_points = json.load(f)
        points_px = np.asarray(tracks_points["data_pixels"][tool_id])
    else:
        points_px = np.asarray(points_px)

    logger.debug(f"{points_px.shape=}")
    logger.debug(f"{pix_size_m=}")
    if points_px.size < 8:
        return None, None
    # points_m = points_px * pix_size_m

    pts_gt = np.load(HEATMAP_EXPERT_POINTS_PATH)

    plt.figure()

    if image is None:
        fn_small = list(outputdir.glob("__cropped.*.jpg"))[0]
        image = skimage.io.imread(fn_small, as_gray=True)
    else:
        if image.ndim == 3:
            image = skimage.color.rgb2gray(image)
    plt.imshow(image, cmap='gray')
    plt.plot(points_px[:, 0], points_px[:, 1], ".", alpha=0.2, color="red", markersize=1)
    # alpha=0.5, markerfacecolor=(1,1,0,0.1)
    # )
    # save dimensions of the plot
    pts_px = (pts_gt / pix_size_m) + np.median(points_px, axis=0)
    sns.kdeplot(x=points_px[::10,0], y=points_px[::10,1],
                # cmap=None,
                cmap=cmap,
                fill=True, bw_adjust=2., levels=levels,alpha=0.5)
    sns.kdeplot(x=pts_px[::10,0], y=pts_px[::10,1], cmap=cmap, fill=False, bw_adjust=2.0, levels=levels)
    points_normed = (points_px - np.median(points_px, axis=0)) * pix_size_m

    l2_distance = compare_distributions_by_l2_distance(points_normed, pts_gt, bw_adjust1=2.0, bw_adjust2=2.0)
    sigma = np.mean(np.var(pts_gt))
    sigma = 2000.0
    score = np.exp( - l2_distance / sigma)
    score_100 = 100 * score
    plt.text(0.02 * image.shape[1], 0.98 * image.shape[0], f"{score_100:.0f}%", fontsize=12, color="red")

    plt.xlim(0, image.shape[1])
    plt.ylim(image.shape[0], 0)
    # turn off axis
    plt.axis("off")
    if filename:
        plt.savefig(filename, dpi=300, bbox_inches="tight", pad_inches=0)
        plt.close()
    return l2_distance, score

# %%
outputdir
# Out:
# PosixPath('/webapps/piglegsurgery/piglegsurgeryweb/media/SA_20240820-093944_ahq68n26lndl/SA_20240820-093944')

# %% [markdown]
# # One data

# %%
patch = Path(fn).stem
outputdir, mediafile_path = get_outputdir(patch)
with open(outputdir / "tracks_points.json", "r") as f:
    tracks_points = json.load(f)
with open(outputdir / "meta.json", "r") as f:
    meta = json.load(f)
with open(outputdir / "results.json", "r") as f:
    results = json.load(f)

if "qr_data" not in meta:
    print(f"Skipping {patch}")
pix_size_m = meta["qr_data"]["pix_size"]

points_px = np.asarray(tracks_points["data_pixels"][0])
points_normed = (points_px - np.median(points_px, axis=0)) * pix_size_m

st_starts = meta["stitch_split_frames"][1::2]
st_ends = meta["stitch_split_frames"][1::2]

# %%
tracks_points[]
# Out:
# dict_keys(['frame_ids', 'data_pixels'])

# %%
results
# Out:
# {'Video duration [s]': 51.266666666666666,
#  'Video start at [s]': 0.0,
#  'Needle holder video area presence [%]': 85.90831918505943,
#  'Needle holder video median area presence [%]': 97.45331069609507,
#  'Needle holder video length [m]': 2.0852352665461873,
#  'Needle holder video visibility [s]': 39.266666666666666,
#  'Needle holder video velocity': 0.04801950124106976,
#  'Needle holder video velocity std': 5.989001904301188,
#  'Needle holder video velocity above threshold': 14,
#  'Needle holder video velocity threshold [m/s]': 0.03,
#  'Needle holder video unit': 'm',
#  'Needle holder video visibility [%]': 76.59297789336802,
#  'Needle holder video heatmap score [%]': 82.64557164428017,
#  'Needle holder video heatmap l2 distance [-]': 82.64557164428017,
#  'Forceps video area presence [%]': 88.71473354231975,
#  'Forceps video median area presence [%]': 99.68652037617555,
#  'Forceps video length [m]': 0.41610118011942254,
#  'Forceps video visibility [s]': 21.266666666666666,
#  'Forceps video velocity': 0.01673824068722146,
#  'Forceps video velocity std': 1.727952540557016,
#  'Forceps video velocity above threshold': 7,
#  'Forceps video velocity threshold [m/s]': 0.03,
#  'Forceps video unit': 'm',
#  'Forceps video visibility [%]': 41.482444733420024,
#  'Forceps video heatmap score [%]': 29.59547263923345,
#  'Forceps video heatmap l2 distance [-]': 29.59547263923345,
#  'Stitch 0 duration [s]': 48.0,
#  'Stitch 0 start at [s]': 2.0,
#  'Needle holder stitch 0 area presence [%]': 85.90831918505943,
#  'Needle holder stitch 0 median area presence [%]': 97.45331069609507,
#  'Needle holder stitch 0 length [m]': 2.0852352665461873,
#  'Needle holder stitch 0 visibility [s]': 39.266666666666666,
#  'Needle holder stitch 0 velocity': 0.04801950124106976,
#  'Needle holder stitch 0 velocity std': 5.989001904301188,
#  'Needle holder stitch 0 velocity above threshold': 14,
#  'Needle holder stitch 0 velocity threshold [m/s]': 0.03,
#  'Needle holder stitch 0 unit': 'm',
#  'Needle holder stitch 0 visibility [%]': 81.80555555555556,
#  'Needle holder stitch 0 heatmap score [%]': 82.64557164428017,
#  'Needle holder stitch 0 heatmap l2 distance [-]': 82.64557164428017,
#  'Forceps stitch 0 area presence [%]': 88.71473354231975,
#  'Forceps stitch 0 median area presence [%]': 99.68652037617555,
#  'Forceps stitch 0 length [m]': 0.41610118011942254,
#  'Forceps stitch 0 visibility [s]': 21.266666666666666,
#  'Forceps stitch 0 velocity': 0.01673824068722146,
#  'Forceps stitch 0 velocity std': 1.727952540557016,
#  'Forceps stitch 0 velocity above threshold': 7,
#  'Forceps stitch 0 velocity threshold [m/s]': 0.03,
#  'Forceps stitch 0 unit': 'm',
#  'Forceps stitch 0 visibility [%]': 44.30555555555556,
#  'Forceps stitch 0 heatmap score [%]': 29.59547263923345,
#  'Forceps stitch 0 heatmap l2 distance [-]': 29.59547263923345,
#  'Piercing 0 duration [s]': 22.0,
#  'Piercing 0 start at [s]': 2.0,
#  'Needle holder piercing 0 area presence [%]': 94.89795918367348,
#  'Needle holder piercing 0 median area presence [%]': 98.29931972789116,
#  'Needle holder piercing 0 length [m]': 0.698848942382247,
#  'Needle holder piercing 0 visibility [s]': 19.6,
#  'Needle holder piercing 0 velocity': 0.035777249610012676,
#  'Needle holder piercing 0 velocity std': 5.5009963807128655,
#  'Needle holder piercing 0 velocity above threshold': 7,
#  'Needle holder piercing 0 velocity threshold [m/s]': 0.03,
#  'Needle holder piercing 0 unit': 'm',
#  'Needle holder piercing 0 visibility [%]': 89.0909090909091,
#  'Needle holder piercing 0 heatmap score [%]': 64.0958684582379,
#  'Needle holder piercing 0 heatmap l2 distance [-]': 64.0958684582379,
#  'Forceps piercing 0 area presence [%]': 89.80891719745223,
#  'Forceps piercing 0 median area presence [%]': 100.0,
#  'Forceps piercing 0 length [m]': 0.3287230509162438,
#  'Forceps piercing 0 visibility [s]': 20.933333333333334,
#  'Forceps piercing 0 velocity': 0.015753500842631493,
#  'Forceps piercing 0 velocity std': 1.5468774320662009,
#  'Forceps piercing 0 velocity above threshold': 6,
#  'Forceps piercing 0 velocity threshold [m/s]': 0.03,
#  'Forceps piercing 0 unit': 'm',
#  'Forceps piercing 0 visibility [%]': 95.15151515151516,
#  'Forceps piercing 0 heatmap score [%]': 26.903881930275215,
#  'Forceps piercing 0 heatmap l2 distance [-]': 26.903881930275215,
#  'Knot 0 duration [s]': 26.0,
#  'Knot 0 start at [s]': 24.0,
#  'Needle holder knot 0 area presence [%]': 77.02702702702703,
#  'Needle holder knot 0 median area presence [%]': 96.62162162162163,
#  'Needle holder knot 0 length [m]': 1.3863863241639398,
#  'Needle holder knot 0 visibility [s]': 19.733333333333334,
#  'Needle holder knot 0 velocity': 0.06017875455598409,
#  'Needle holder knot 0 velocity std': 6.2035000744002895,
#  'Needle holder knot 0 velocity above threshold': 6,
#  'Needle holder knot 0 velocity threshold [m/s]': 0.03,
#  'Needle holder knot 0 unit': 'm',
#  'Needle holder knot 0 visibility [%]': 75.89743589743591,
#  'Needle holder knot 0 heatmap score [%]': 88.34913684814451,
#  'Needle holder knot 0 heatmap l2 distance [-]': 88.34913684814451,
#  'Forceps knot 0 area presence [%]': 16.666666666666664,
#  'Forceps knot 0 median area presence [%]': 83.33333333333334,
#  'Forceps knot 0 length [m]': 0.08737812920317874,
#  'Forceps knot 0 visibility [s]': 0.4,
#  'Forceps knot 0 velocity': 0.07838295495855319,
#  'Forceps knot 0 velocity std': 2.226868073635999,
#  'Forceps knot 0 velocity above threshold': 0,
#  'Forceps knot 0 velocity threshold [m/s]': 0.03,
#  'Forceps knot 0 unit': 'm',
#  'Forceps knot 0 visibility [%]': 1.5384615384615385,
#  'Forceps knot 0 heatmap score [%]': 58.59322398051757,
#  'Forceps knot 0 heatmap l2 distance [-]': 58.59322398051757,
#  'Static quality stitch 0': 1,
#  'Needle holder to forceps distance threshold [m]': 0.03,
#  'Needle holder to forceps stitch 0 average distance [m]': 0.014196858012727586,
#  'Needle holder to forceps stitch 0 below threshold [s]': 20.333333333333332,
#  'Needle holder to forceps stitch 0 below threshold [%]': 42.36111111111111,
#  'Needle holder to forceps piercing 0 average distance [m]': 0.013036892089614355,
#  'Needle holder to forceps piercing 0 below threshold [s]': 18.8,
#  'Needle holder to forceps piercing 0 below threshold [%]': 85.45454545454547,
#  'Needle holder to forceps knot 0 average distance [m]': 0.023614692327852262,
#  'Needle holder to forceps knot 0 below threshold [s]': 1.6,
#  'Needle holder to forceps knot 0 below threshold [%]': 6.153846153846154,
#  'Stitches linearity score [%]': 50.3617047605047,
#  'Stitches parallelism score [%]': 99.82370950920104,
#  'Stitches perpendicular score [%]': 66.66666666666667,
#  'AI movement evaluation stitch 0 [%]': 84.4606270167468}

# %%
# the actual (old) stored values
pts_gt = np.load(HEATMAP_EXPERT_POINTS_PATH)
plt.plot(pts_gt[:,0], pts_gt[:,1], ".")
pts_gt.shape
# Out:
# (16236, 2)

# %%
dfall_expert = dfall[dfall["done_by_expert"]==True]["filename"].values

fn = dfall_expert[5]

# points_expert = []
# for fn in dfall_expert:
patch = Path(fn).stem
outputdir, mediafile_path = get_outputdir(patch)
with open(outputdir / "tracks_points.json", "r") as f:
    tracks_points = json.load(f)
with open(outputdir / "meta.json", "r") as f:
    meta = json.load(f)
with open(outputdir / "results.json", "r") as f:
    results = json.load(f)

if "qr_data" not in meta:
    print(f"Skipping {patch}")
    continue
pix_size_m = meta["qr_data"]["pix_size"]

points_px = np.asarray(tracks_points["data_pixels"][0])
points_normed = (points_px - np.median(points_px, axis=0)) * pix_size_m
# points_expert.append(points_normed)
#
# points_expert = np.concatenate(points_expert)
# print(points_expert.shape)


plt.plot(points_expert[:,0], points_expert[:,1], ".")
plt.figure()


sns.kdeplot(x=points_expert[::10,0], y=points_expert[::10,1], cmap="Greens", fill=True, bw_adjust=1., levels=3,alpha=0.5)
# Out:
# Skipping Ekn_Ana_1
# Skipping Ekn_Ana_2
# Skipping Ekn_Ana_3
# Skipping Ekn_Ana_4
# Skipping Ekn_Ana_5
# Skipping Ekn_Ana_7
# Skipping Ekn_Ana_10
# Skipping Ekn_Ana_6
# Skipping Ekn_Ana_12
# Skipping Ekn_Ana_14
# Skipping Ekn_Ana_11
# Skipping Ekn_Ana_15
# Skipping Ekn_Ana_18
# Skipping Ekn_Ana_20
# Skipping Ekn_Ana_16
# Skipping Ekn_Ana_17
# Skipping Ekn_Ana_21
# Skipping Ekn_Ana_22
# Skipping Ekn_CSW_4
# Skipping Ekn_CSW_2
# (4273, 2)
# <AxesSubplot:>

# %%
compare_heatmaps_plot(outputdir, points_px=None, pix_size_m=None, filename=None, image=None, tool_id=0, cmap="Greens", levels=3)
# Out:
# 2025-02-12 13:43:34.288 | DEBUG    | __main__:compare_heatmaps_plot:52 - points_px.shape=(589, 2)
# 2025-02-12 13:43:34.289 | DEBUG    | __main__:compare_heatmaps_plot:53 - pix_size_m=0.0003860936734953825
# (946.1528906252333, 0.6230824376252699)

# %%
with open(outputdir / "meta.json", "r") as f:
    meta = json.load(f)
meta
# Out:
# {'filename_full': '/webapps/piglegsurgery/piglegsurgeryweb/media/upload/20240820-093944_Ekn_Ana_12_663fae963c61a619fce961ce7f857a7539fc2b52/Ekn_Ana_12.mp4',
#  'fps': 30,
#  'frame_count': 1447}
